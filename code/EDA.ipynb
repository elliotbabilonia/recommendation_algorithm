# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Identified and addressed missing values in the dataset using the `isnull().sum()` function. Ensured data completeness and integrity by handling missing values appropriately.
#
# For the dataset information, I obtained an overview of the dataset structure, data types, and non-null counts using the `.info()` method. Then, I gained insights into the dataset's characteristics and potential data preprocessing requirements. I did descriptive statistics, conducting a summary statistical analysis of numerical features using the `.describe()` method. Afterwards, I got key statistical metrics such as mean, median, minimum, maximum, and quartiles for numerical variables.
#
# ### Data Cleaning:
# I identified and dropped unnecessary columns from the dataset, such as the 'Unnamed: 0' column, using appropriate methods. I improved dataset clarity and reduced dimensionality by removing redundant or irrelevant columns.
#
# The EDA process provided valuable insights into the dataset's structure, content, and quality, laying the groundwork for further analysis and modeling tasks. The dataset contained 24 columns with various data types. Columns like 'Unnamed: 0' were removed as they didn't provide useful information. The 'release_date' column was converted to datetime format for further analysis. Data types and column names were checked to ensure consistency.

# %%
import pandas as pd
df = pd.read_csv("../data/train.csv")
df.head(15000)
# Out:
#        Unnamed: 0                  artist_name                 track_name  \
# 0               0                       mukesh       mohabbat bhi jhoothi
# 1               4                frankie laine                  i believe
# 2               6                  johnnie ray                        cry
# 3              10                  pérez prado                   patricia
# 4              12         giorgos papadopoulos         apopse eida oneiro
# ...           ...                          ...                        ...
# 14995       47896                     dr. john             milneburg joys
# 14996       47897                    dead moon  fire in the western world
# 14997       47899                     dr. john       since i fell for you
# 14998       47901                      santana                    milagro
# 14999       47907  robben ford & the blue line             prison of love
#
#        release_date  genre                                             lyrics  \
# 0              1950    pop  hold time feel break feel untrue convince spea...
# 1              1950    pop  believe drop rain fall grow believe darkest ni...
# 2              1950    pop  sweetheart send letter goodbye secret feel bet...
# 3              1950    pop  kiss lips want stroll charm mambo chacha merin...
# 4              1950    pop  till darling till matter know till dream live ...
# ...             ...    ...                                                ...
# 14995          1992  blues  soul milneburg joy soul milneburg joy play mam...
# 14996          1992  blues  moan wind blow hard better warn cause time go ...
# 14997          1992  blues  know darlin leave home take go fell bring mise...
# 14998          1992  blues  work work work work heal people music free peo...
# 14999          1992  blues  good thing abuse gentle ways leave need leave ...
#
#        len    dating  violence  world/life  ...  communication   obscene  \
# 0       95  0.000598  0.063746    0.000598  ...       0.263751  0.000598
# 1       51  0.035537  0.096777    0.443435  ...       0.001284  0.001284
# 2       24  0.002770  0.002770    0.002770  ...       0.250668  0.002770
# 3       54  0.048249  0.001548    0.001548  ...       0.001548  0.001548
# 4       48  0.001350  0.001350    0.417772  ...       0.001350  0.001350
# ...    ...       ...       ...         ...  ...            ...       ...
# 14995   31  0.002770  0.002770    0.002770  ...       0.002770  0.002770
# 14996   67  0.001144  0.447526    0.164416  ...       0.092367  0.001144
# 14997   33  0.151763  0.001645    0.001645  ...       0.001645  0.001645
# 14998   22  0.002288  0.002288    0.002288  ...       0.002288  0.002288
# 14999   56  0.001284  0.001284    0.001284  ...       0.099271  0.001284
#
#           music  movement/places  light/visual perceptions  family/spiritual  \
# 0      0.039288         0.000598                  0.000598          0.000598
# 1      0.118034         0.001284                  0.212681          0.051124
# 2      0.323794         0.002770                  0.002770          0.002770
# 3      0.001548         0.129250                  0.001548          0.001548
# 4      0.001350         0.001350                  0.001350          0.029755
# ...         ...              ...                       ...               ...
# 14995  0.424345         0.002770                  0.002770          0.002770
# 14996  0.001144         0.179904                  0.001144          0.001144
# 14997  0.144977         0.001645                  0.161957          0.001645
# 14998  0.350114         0.002288                  0.002288          0.350114
# 14999  0.001284         0.001284                  0.001284          0.026631
#
#         sadness  feelings       topic  age
# 0      0.380299  0.117175     sadness  1.0
# 1      0.001284  0.001284  world/life  1.0
# 2      0.002770  0.225422       music  1.0
# 3      0.225889  0.001548    romantic  1.0
# 4      0.068800  0.001350    romantic  1.0
# ...         ...       ...         ...  ...
# 14995  0.002770  0.108222       music  0.4
# 14996  0.001144  0.001144    violence  0.4
# 14997  0.419940  0.001645     sadness  0.4
# 14998  0.002288  0.002288       music  0.4
# 14999  0.427337  0.120922     sadness  0.4
#
# [15000 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# artist_name                 0
# track_name                  0
# release_date                0
# genre                       0
# lyrics                      0
# len                         0
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# sadness                     0
# feelings                    0
# topic                       0
# age                         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28362 entries, 0 to 28361
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28362 non-null  int64
#  1   artist_name               28362 non-null  object
#  2   track_name                28362 non-null  object
#  3   release_date              28362 non-null  int64
#  4   genre                     28362 non-null  object
#  5   lyrics                    28362 non-null  object
#  6   len                       28362 non-null  int64
#  7   dating                    28362 non-null  float64
#  8   violence                  28362 non-null  float64
#  9   world/life                28362 non-null  float64
#  10  night/time                28362 non-null  float64
#  11  shake the audience        28362 non-null  float64
#  12  family/gospel             28362 non-null  float64
#  13  romantic                  28362 non-null  float64
#  14  communication             28362 non-null  float64
#  15  obscene                   28362 non-null  float64
#  16  music                     28362 non-null  float64
#  17  movement/places           28362 non-null  float64
#  18  light/visual perceptions  28362 non-null  float64
#  19  family/spiritual          28362 non-null  float64
#  20  sadness                   28362 non-null  float64
#  21  feelings                  28362 non-null  float64
#  22  topic                     28362 non-null  object
#  23  age                       28362 non-null  float64
# dtypes: float64(16), int64(3), object(5)
# memory usage: 5.2+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  release_date           len        dating      violence  \
# count  28362.000000  28362.000000  28362.000000  28362.000000  28362.000000
# mean   42948.166878   1990.239652     73.030534      0.021110      0.118371
# std    24747.811462     18.486997     41.831605      0.052366      0.178658
# min        0.000000   1950.000000      1.000000      0.000291      0.000284
# 25%    20393.500000   1975.000000     42.000000      0.000923      0.001120
# 50%    45407.000000   1991.000000     63.000000      0.001462      0.002506
# 75%    64089.500000   2007.000000     93.000000      0.004049      0.192538
# max    82451.000000   2019.000000    199.000000      0.647706      0.981781
#
#          world/life    night/time  shake the audience  family/gospel  \
# count  28362.000000  28362.000000        28362.000000   28362.000000
# mean       0.120984      0.057356            0.017418       0.017045
# std        0.172216      0.111892            0.040658       0.041968
# min        0.000291      0.000289            0.000284       0.000289
# 25%        0.001170      0.001032            0.000993       0.000923
# 50%        0.006579      0.001949            0.001595       0.001504
# 75%        0.197854      0.065778            0.009989       0.004785
# max        0.962105      0.973684            0.497463       0.545303
#
#            romantic  communication       obscene         music  \
# count  28362.000000   28362.000000  28362.000000  28362.000000
# mean       0.048676       0.076651      0.097185      0.060067
# std        0.106071       0.109497      0.181314      0.123346
# min        0.000284       0.000291      0.000289      0.000289
# 25%        0.000975       0.001144      0.001053      0.000975
# 50%        0.001754       0.002632      0.001815      0.001815
# 75%        0.042304       0.132111      0.088799      0.055109
# max        0.940789       0.645829      0.992298      0.956938
#
#        movement/places  light/visual perceptions  family/spiritual  \
# count     28362.000000              28362.000000      28362.000000
# mean          0.047417                  0.049008          0.024155
# std           0.091559                  0.089553          0.051032
# min           0.000284                  0.000284          0.000284
# 25%           0.000993                  0.000993          0.000957
# 50%           0.001645                  0.001815          0.001645
# 75%           0.054373                  0.064302          0.025515
# max           0.638021                  0.667782          0.618073
#
#             sadness      feelings           age
# count  28362.000000  28362.000000  28362.000000
# mean       0.129402      0.030995      0.425148
# std        0.181149      0.071656      0.264100
# min        0.000284      0.000289      0.014286
# 25%        0.001144      0.000993      0.185714
# 50%        0.005263      0.001754      0.414286
# 75%        0.235115      0.032617      0.642857
# max        0.981424      0.958810      1.000000

# %%
def clean_artist_data(df):
    df = df.drop(columns=['Unnamed: 0', 'lyrics'])
    return df

cleaned_df = clean_artist_data(df)
cleaned_df.to_csv('cleaned_data.csv', index=False)
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28362 entries, 0 to 28361
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   artist_name               28362 non-null  object
#  1   track_name                28362 non-null  object
#  2   release_date              28362 non-null  int64
#  3   genre                     28362 non-null  object
#  4   len                       28362 non-null  int64
#  5   dating                    28362 non-null  float64
#  6   violence                  28362 non-null  float64
#  7   world/life                28362 non-null  float64
#  8   night/time                28362 non-null  float64
#  9   shake the audience        28362 non-null  float64
#  10  family/gospel             28362 non-null  float64
#  11  romantic                  28362 non-null  float64
#  12  communication             28362 non-null  float64
#  13  obscene                   28362 non-null  float64
#  14  music                     28362 non-null  float64
#  15  movement/places           28362 non-null  float64
#  16  light/visual perceptions  28362 non-null  float64
#  17  family/spiritual          28362 non-null  float64
#  18  sadness                   28362 non-null  float64
#  19  feelings                  28362 non-null  float64
#  20  topic                     28362 non-null  object
#  21  age                       28362 non-null  float64
# dtypes: float64(16), int64(2), object(4)
# memory usage: 4.8+ MB
